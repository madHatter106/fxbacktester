# %%
from decimal import Decimal, getcontext, ROUND_HALF_DOWN
from fxbacktester.random_forecast import RandomForecastingStrategy
from fxbacktester.position import Position
import pandas as pd
import os
import glob

# %%
maindir = '/Users/PoFA/DATAFILES/FX/OANDA/'
# maindir = os.getenv('OANDA_DATA_MAIN')
datalist = glob.glob(os.path.join(maindir,'*'))
datalist
# Out:
# ['/Users/PoFA/DATAFILES/FX/OANDA/AUD_USD_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/CAD_JPY_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/EUR_CAD_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/EUR_JPY_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/EUR_USD_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/GBP_USD_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/USD_CHF_170101_170101_1H.h5s',
#  '/Users/PoFA/DATAFILES/FX/OANDA/USD_JPY_170101_170101_1H.h5s']

# %%
symbol='AUD_USD'
file=datalist[0]

# %%
dfau = pd.read_hdf(file)
dfau.drop(['time', 'complete'], inplace=True, axis=1)

# %%
dfau.head()
# Out:
#                      closeAsk  closeBid  highAsk  highBid   lowAsk   lowBid  \
# 2017-01-02 23:00:00   0.71970   0.71950  0.72045  0.72026  0.71935  0.71916
# 2017-01-03 00:00:00   0.71955   0.71939  0.72048  0.72031  0.71954  0.71936
# 2017-01-03 01:00:00   0.72175   0.72158  0.72178  0.72163  0.71953  0.71939
# 2017-01-03 02:00:00   0.72257   0.72240  0.72266  0.72248  0.72166  0.72150
# 2017-01-03 03:00:00   0.72306   0.72294  0.72326  0.72310  0.72245  0.72229
#
#                      openAsk  openBid  volume
# 2017-01-02 23:00:00  0.71998  0.71963     453
# 2017-01-03 00:00:00  0.71966  0.71944     300
# 2017-01-03 01:00:00  0.71959  0.71942     559
# 2017-01-03 02:00:00  0.72170  0.72153     305
# 2017-01-03 03:00:00  0.72252  0.72237     243

# %%
rfs = RandomForecastingStrategy(symbol=symbol, bars=dfau )

# %%
dfsig= rfs.generate_signals()

# %%
dfsig.head()
# Out:
#                      signal
# 2017-01-02 23:00:00    -1.0
# 2017-01-03 00:00:00     1.0
# 2017-01-03 01:00:00     1.0
# 2017-01-03 02:00:00     1.0
# 2017-01-03 03:00:00     1.0

# %%
pos= Position('long', symbol, units=1, exposure=0.02, bid=dfau.openBid[0], ask=dfau.openAsk[0])

# %%
pos.profit_perc
# Out:
# Decimal('-4.85000')

# %%
from fxbacktester.VectorizedBacktester.strategies import movingaveragestrategy

# %%
from fxbacktester.VectorizedBacktester.backtesters import vectorizedbacktest

# %%
strategy_params={'short_window': 1, 'long_window': 5}

# %%
data = dfau[['closeBid', 'closeAsk']]

# %%
test = vectorizedbacktest(data, movingaveragestrategy, strategy_params)

# %%
test.runtest()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2f128008eb8a> in <module>()
# ----> 1 test.runtest()
#
# /Users/PoFA/anaconda/lib/python3.6/site-packages/fxbacktester/VectorizedBacktester/backtesters.py in runtest(self)
#       8     def runtest(self):
#       9         self.result = self.strategy.generate_signal()
# ---> 10         self.result['tradeID'] = (~(self.result['signal'] ==
#      11                                     self.result['signal'].shift(1))).cumsum()
#      12         self.result['return'] = np.log(self.result['closeMid'] /
#
# TypeError: 'NoneType' object is not subscriptable

# %%
re = test.strategy.generate_signal()

# %%
test.strategy.data
# Out:
#                      closeBid  closeAsk  signal  closeMid    fastma    slowma
# 2017-01-03 07:00:00   0.72133   0.72150      -1  0.721415  0.721415  0.722853
# 2017-01-03 08:00:00   0.72127   0.72143      -1  0.721350  0.721350  0.722523
# 2017-01-03 09:00:00   0.72048   0.72062      -1  0.720550  0.720550  0.721964
# 2017-01-03 10:00:00   0.72018   0.72032      -1  0.720250  0.720250  0.721418
# 2017-01-03 11:00:00   0.72072   0.72088      -1  0.720800  0.720800  0.720873
# 2017-01-03 12:00:00   0.72173   0.72189       1  0.721810  0.721810  0.720952
# 2017-01-03 13:00:00   0.72122   0.72137       1  0.721295  0.721295  0.720941
# 2017-01-03 14:00:00   0.72206   0.72255       1  0.722305  0.722305  0.721292
# 2017-01-03 15:00:00   0.72193   0.72205       1  0.721990  0.721990  0.721640
# 2017-01-03 16:00:00   0.72293   0.72308       1  0.723005  0.723005  0.722081
# 2017-01-03 17:00:00   0.72362   0.72377       1  0.723695  0.723695  0.722458
# ...
